# %% [markdown]
# # Temporary Colab Debug Shell
#
# Run this in a fresh Colab runtime if the normal launcher keeps disconnecting. It downloads a static `tmate` binary, starts a temporary shared shell, and prints an SSH command. Share only the SSH command if you want someone to debug inside this Colab runtime.

# %%
REPO_URL = "https://github.com/Cobster-10/custom_llm.git"
REPO_DIR = "/content/custom_llm"

from pathlib import Path

if Path(REPO_DIR, ".git").exists():
    # !git -C {REPO_DIR} pull --ff-only
else:
    # !git clone {REPO_URL} {REPO_DIR}

# %cd {REPO_DIR}

# %%
# !cd /content/custom_llm && bash scripts/start_tmate_debug.sh
